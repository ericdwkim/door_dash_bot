# %%
from src.utils.order_handler import OrderHandler
from src.utils.data_merger import DataMerger

oh = OrderHandler()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       2 from src.utils.data_merger import DataMerger
#       4 oh = OrderHandler()
# ----> 6 dm = DataMerger()
#
# TypeError: DataMerger.__init__() missing 1 required positional argument: 'orders_json'

# %%
json_orders = [
    {
        "Order": "F7993DCD",
        "Delivered": "The order was delivered at 11:00 PM on October 22, 2023.",
        "Pick Up Location": "800 W Interstate 20, Big Spring, TX 79720, USA",
        "Order Details": {
            "2 \u00d7 TXB Water Bottle (1gal) (Water TX)": "$6.58"
        },
        "Subtotal": "$6.58",
        "Subtotal Tax": "$0.00",
        "Commission (16%)": "-$1.05",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$5.53",
        "Transaction #8273699085 - Delivery": "$5.53"
    },
    {
        "Order": "34D9C5E4",
        "Delivered": "The order was delivered at 10:24 PM on October 22, 2023.",
        "Pick Up Location": "5004 Wesley St, Greenville, TX 75402, USA",
        "Order Details": {
            "1 \u00d7 Ghost Sour Patch Redberry Can (16oz) (Energy Drinks TX)": "$4.99",
            " 1 \u00d7 Ghost Sour Patch Blue Raspberry Can (16oz) (Energy Drinks TX)": "$4.99"
        },
        "Subtotal": "$9.98",
        "Subtotal Tax": "$0.82",
        "Commission (16%)": "-$1.60",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$9.20",
        "Transaction #8273552428 - Delivery": "$9.20"
    },
    {
        "Order": "3BAAECB0",
        "Delivered": "The order was delivered at 10:18 PM on October 22, 2023.",
        "Pick Up Location": "2503 TX-349, Midland, TX 79706, USA",
        "Order Details": {
            "1 \u00d7 Michelob Ultra Light Beer Bottle (12 oz x 12 ct) (Domestic Beer 71)": "$26.29"
        },
        "Subtotal": "$26.29",
        "Subtotal Tax": "$2.10",
        "Commission (23%)": "-$6.05",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$22.34",
        "Transaction #8273530360 - Delivery": "$22.34"
    },
    {
        "Order": "250FFDBB",
        "Delivered": "The order was delivered at 10:07 PM on October 22, 2023.",
        "Pick Up Location": "5004 Wesley St, Greenville, TX 75402, USA",
        "Order Details": {
            "1 \u00d7 ZZZQuil Sleep Aid Liquid Capsules (12ct) (Medicine TX)": "$14.89",
            " 1 \u00d7 Vicks Nyquil Liquid (8oz) (Medicine TX)": "$11.29"
        },
        "Subtotal": "$26.18",
        "Subtotal Tax": "$0.00",
        "Commission (23%)": "-$6.02",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$20.16",
        "Transaction #8273409817 - Delivery": "$20.16"
    },
    {
        "Order": "43A67EFC",
        "Delivered": "Error Charge The customer reported one or more missing items resulting in an error charge of $6.81. If you believe this was an error, you can dispute the error charge by November 5, 2023.",
        "Pick Up Location": "1402 Williams Dr, Georgetown, TX 78628, USA",
        "Order Details": {
            "1 \u00d7 Chef Boyardee Beef Ravioli (15oz) (Pantry TX)": "$5.39",
            " 1 \u00d7 Muscle Milk Protein Vanilla Shake (14oz) (Milk TX)": "$6.29",
            " 2 \u00d7 Black Box Chardonnay Tetra 500ml Box (13.5% ABV) (Specialty Wine)": "$12.58",
            " 1 \u00d7 Chicken Tender Meal Kit (Meal Kits TXB#65)": "$9.19"
        },
        "Subtotal": "-$6.30 Error Charge Tax -$0.51 Error Charge Total -$6.81 Order Total $30.41",
        "Commission (16%)": "-$5.35 Order Total $30.41 Error Charges 2 \u00d7 Black Box Chardonnay Tetra 500ml Box (13.5% ABV) (Specialty Wine) Missing Item -$6.30 Error Charge",
        "Estimated Payout": "$23.60",
        "Transaction #8272588460 - Delivery": "$30.41 Transaction #8272685556 - Error Charges -$6.81"
    },
    {
        "Order": "7E9C8842",
        "Cancelled - Not Paid": "The order was cancelled on October 22, 2023 at 7:58 PM. You were not paid because you did not confirm the order before the order was cancelled.",
        "Pick Up Location": "",
        "Order Details": {
            "1 \u00d7 Miller Lite Beer Can (12 oz x 18 ct) (Domestic Beer 71)": "$28.79"
        },
        "Subtotal": "$28.79",
        "Subtotal Tax": "$2.30",
        "Commission (16%)": "-$4.61",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$0.00"
    },
    {
        "Order": "E4047327",
        "Could Not Deliver": "The Dasher attempted to deliver to your customer, but couldn't complete the delivery.",
        "Pick Up Location": "2503 TX-349, Midland, TX 79706, USA",
        "Order Details": {
            "1 \u00d7 Miller Lite Beer Can (12 oz x 18 ct) (Domestic Beer 71)": "$28.79"
        },
        "Subtotal": "$28.79",
        "Subtotal Tax": "$2.30",
        "Commission (16%)": "-$4.61",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$26.48",
        "Transaction #8272194075 - Delivery": "$26.48"
    },
    {
        "Order": "84176DEA",
        "Delivered": "The order was delivered at 7:14 PM on October 22, 2023.",
        "Pick Up Location": "14417 State Hwy 71, Austin, TX 78738, USA",
        "Order Details": {
            "1 \u00d7 Bota Box Mini Chardonnay 500ml Box (8% ABV) (Wine)": "$6.29",
            " 1 \u00d7 Large Specialty Pizza Unlimited Topping (Hunt Brothers TXB#55) Toppings: Meat Lovers Toppings: Pepperoni Toppings: Bacon Toppings: Beef Toppings: Sausage Toppings: Green Peppers": "$15.09"
        },
        "Subtotal": "$21.38",
        "Subtotal Tax": "$1.76",
        "Commission (23%)": "-$4.92",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$18.22",
        "Transaction #8271835713 - Delivery": "$18.22"
    },
    {
        "Order": "E5184A48",
        "Cancelled - Not Paid": "The order was cancelled on October 22, 2023 at 6:46 PM. You were not paid because because staff requested to cancel.",
        "Pick Up Location": "2965 S Church St, Paris, TX 75462, USA",
        "Order Details": {
            "1 \u00d7 Smirnoff Ice Original Malt Beverage Bottle (11.2 oz x 6 ct) (Flavored Malt Beverages NT)": "$16.29"
        },
        "Subtotal": "$16.29",
        "Subtotal Tax": "$1.34",
        "Commission (16%)": "-$2.61",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$0.00"
    },
    {
        "Order": "B2955303",
        "Delivered": "The order was delivered at 6:24 PM on October 22, 2023.",
        "Pick Up Location": "3702 FM2147, Horseshoe Bay, TX 78657, USA",
        "Order Details": {
            "1 \u00d7 Chicken Tender Family Meal (10 pcs) (Chicken TXB#67) Dipping Sauce: Chicken Dipping Sauce Dipping Sauce: Ranch Dipping Sauce Dipping Sauce: Buffalo Dipping Sauce Choice of Sides: Mac & Cheese Original or Spicy: Original": "$31.29"
        },
        "Subtotal": "$31.29",
        "Subtotal Tax": "$2.58",
        "Commission (25%)": "-$7.82",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$26.05",
        "Transaction #8271256372 - Delivery": "$26.05"
    },
    {
        "Order": "4D5A8FB6",
        "Cancelled - Not Paid": "The order was cancelled on October 22, 2023 at 5:01 PM. You were not paid because you were unable to fulfill the order.",
        "Pick Up Location": "21024 W, 21024 State Hwy 71, Spicewood, TX 78669, USA",
        "Order Details": {
            "4 \u00d7 Fiji Natural Artesian Water Bottle (1 lt) (Water TX)": "$19.96",
            " 1 \u00d7 Chicken Fajita Quesadilla (Quesadillas TXB#62) Salsa: Sour Cream": "$7.49",
            " 1 \u00d7 Smokehouse Brisket Sandwich (Hot Sandwiches TXB#62)": "$8.69",
            " 1 \u00d7 Pork Tamale Meal Kit (Meal Kits TXB#62)": "$9.19",
            " 1 \u00d7 Chicken Tender Family Meal (10 pcs) (Chicken TXB#62) Dipping Sauce: Chicken Dipping Sauce Dipping Sauce: BBQ Dipping Sauce Dipping Sauce: Buffalo Dipping Sauce Dipping Sauce: Boom-Boom Dipping Sauce Original or Spicy: Original": "$31.29",
            " 4 \u00d7 Dr Pepper Bottle (20 oz) (Soda TX)": "$15.16"
        },
        "Subtotal": "$91.78",
        "Subtotal Tax": "$5.93",
        "Commission (23%)": "-$21.11",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$0.00"
    },
    {
        "Order": "BAEEEE2F",
        "Delivered": "The order was delivered at 4:59 PM on October 22, 2023.",
        "Pick Up Location": "1402 Williams Dr, Georgetown, TX 78628, USA",
        "Order Details": {
            "1 \u00d7 Fountain Drink (Fountain, Frozen, & Tea) Drink Selection: Dr Pepper": "$2.39",
            " 1 \u00d7 Bang Black Cherry Vanilla Can (16oz) (Energy Drinks TX)": "$4.79"
        },
        "Subtotal": "$7.18",
        "Subtotal Tax": "$0.40",
        "Commission (16%)": "-$1.15",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$6.43",
        "Transaction #8270415286 - Delivery": "$6.43"
    },
    {
        "Order": "BA759227",
        "Delivered": "The order was delivered at 4:49 PM on October 22, 2023.",
        "Pick Up Location": "2320 W Main St, Durant, OK 74701, USA",
        "Order Details": {
            "1 \u00d7 Keystone Light Beer Can (12 oz x 15 ct) (Domestic Beer OK)": "$16.29"
        },
        "Subtotal": "$16.29",
        "Subtotal Tax": "$1.53 Alcohol Fee -$1.00",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$15.29",
        "Transaction #8270236482 - Delivery": "$15.29"
    },
    {
        "Order": "1966D991",
        "Cancelled - Paid": "The order was cancelled on October 22, 2023 at 4:42 PM. You\u2019re paid for cancelled orders when you\u2019ve successfully confirmed an order, it was prepared, and you did not initiate or are not at fault for the cancellation.",
        "Pick Up Location": "500 W Thornton St, Three Rivers, TX 78071, USA",
        "Order Details": {
            "1 \u00d7 TXB Twister Fries (7oz) (Burgers & Fries TXB#79)": "$3.79",
            " 1 \u00d7 Mash Potato & Gravy Medium (Sides TXB#79)": "$3.49"
        },
        "Subtotal": "$7.28",
        "Subtotal Tax": "$0.60",
        "Commission (16%)": "-$1.16",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$6.72",
        "Transaction #8270326630 - Delivery": "$6.72"
    },
    {
        "Order": "09F212B2",
        "Delivered": "The order was delivered at 3:28 PM on October 22, 2023.",
        "Pick Up Location": "5004 Wesley St, Greenville, TX 75402, USA",
        "Order Details": {
            "1 \u00d7 Modelo Especial Lager Beer Can (24 oz) (Import Beer NT)": "$5.69",
            " 1 \u00d7 Twisted Tea Hard Iced Tea Cocktail Original (24 oz) (Flavored Malt Beverages NT)": "$5.69"
        },
        "Subtotal": "$11.38",
        "Subtotal Tax": "$0.94",
        "Commission (16%)": "-$1.82",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$10.50",
        "Transaction #8269614197 - Delivery": "$10.50"
    },
    {
        "Order": "AEE37870",
        "Delivered": "Error Charge The customer reported one or more missing items resulting in an error charge of $10.13. If you believe this was an error, you can dispute the error charge by November 5, 2023.",
        "Pick Up Location": "2320 W Main St, Durant, OK 74701, USA",
        "Order Details": {
            "4 \u00d7 Bud Ice Lager Beer Can (25 oz) (Domestic Beer OK)": "$13.16"
        },
        "Subtotal": "-$10.13 Error Charge Total -$10.13 Order Total $12.16",
        "Estimated Payout": "$2.03",
        "Transaction #8268297292 - Delivery": "$12.16 Transaction #8269172142 - Error Charges -$3.29 Transaction #8269180867 - Error Charges -$6.84"
    },
    {
        "Order": "C914155D",
        "Cancelled - Not Paid": "The order was cancelled on October 22, 2023 at 10:27 AM. You were not paid because you did not confirm the order before the order was cancelled.",
        "Pick Up Location": "3702 FM2147, Horseshoe Bay, TX 78657, USA",
        "Order Details": {
            "1 \u00d7 Coors Light Beer Can (12 oz x 18 ct) (Domestic Beer 53/66/67)": "$29.99",
            " 3 \u00d7 Oscar Mayer Smoked Lean Ham (6 oz) (Protein TX)": "$17.97",
            " 1 \u00d7 Hostess Powdered Donettes Bag (10.5oz) (Donuts TX)": "$6.39",
            " 1 \u00d7 Smuckers Squeezable Grape Jelly (20oz) (Condiments TX)": "$7.19",
            " 1 \u00d7 Jif Cream Peanut butter, 16oz (Condiments TX)": "$5.49",
            " 1 \u00d7 Wheat Bread (16 oz) (Bread & Tortillas TX)": "$4.39",
            " 1 \u00d7 Hostess Chocolate Cupcake 2 pk (3.17oz) (Pastry TX)": "$3.79",
            " 1 \u00d7 Tostitos Salsa Con Queso Dip (15 oz) (Dips & Salsa TX)": "$5.69",
            " 1 \u00d7 Kraft Philadelphia Cream Cheese, 8oz (Cheese TX)": "$8.39",
            " 1 \u00d7 Electrolit Strawberry Kiwi (21oz) (Sports Drinks TX)": "$4.69",
            " 1 \u00d7 Big TX Burrito (Breakfast Tacos & Quesadillas) Salsa: Salsa Roja Salsa: Salsa Verde": "$2.89",
            " 1 \u00d7 TXB Water Bottle (24 pk) (16.9 oz) (Water TX)": "$7.49"
        },
        "Subtotal": "$104.36",
        "Subtotal Tax": "$4.01",
        "Commission (25%)": "-$26.09",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$0.00"
    },
    {
        "Order": "8BCC52F9",
        "Delivered": "The order was delivered at 9:44 AM on October 22, 2023.",
        "Pick Up Location": "21024 W, 21024 State Hwy 71, Spicewood, TX 78669, USA",
        "Order Details": {
            "1 \u00d7 Sausage Egg Cheese Biscuit (Breakfast Sandwiches & Bowls)": "$4.89",
            " 1 \u00d7 Brisket Egg Quesadilla (Breakfast Tacos & Quesadillas)": "$7.49",
            " 2 \u00d7 Breakfast Quesadilla (Breakfast Tacos & Quesadillas) Salsa: Salsa Verde": "$14.98"
        },
        "Subtotal": "$27.36",
        "Subtotal Tax": "$2.26",
        "Commission (23%)": "-$6.29",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$23.33",
        "Transaction #8267260227 - Delivery": "$23.33"
    },
    {
        "Order": "44DD3AA2",
        "Delivered": "The order was delivered at 12:21 AM on October 22, 2023.",
        "Pick Up Location": "2503 TX-349, Midland, TX 79706, USA",
        "Order Details": {
            "1 \u00d7 Coca-Cola Can (12 pk-12 oz) (Soda TX)": "$11.29"
        },
        "Subtotal": "$11.29",
        "Subtotal Tax": "$0.90",
        "Commission (16%)": "-$1.81",
        "Total Customer Refund": "-$0.00",
        "Estimated Payout": "$10.38",
        "Transaction #8266036994 - Delivery": "$10.38"
    }
]

# %%
orders_json = oh.get_prettified_and_mapped_orders(json_orders, is_raw=False)

# %%
dm = DataMerger(orders_json)

# %%
orders_with_store_nums = dm.add_store_numbers_to_orders()
orders_with_store_nums
# Out:
# WARNING:root: Pick Up location is missing from Order. Adding placeholder...
# [{'Order': 'F7993DCD',
#   'Delivered': 'The order was delivered at 11:00 PM on October 22, 2023.',
#   'Pick Up Location': '800 W Interstate 20, Big Spring, TX 79720, USA',
#   'Order Details': {'2 × TXB Water Bottle (1gal) (Water TX)': '$6.58'},
#   'Subtotal': '$6.58',
#   'Subtotal Tax': '$0.00',
#   'Commission (16%)': '-$1.05',
#   'Total Customer Refund': '-$0.00',
#   'Estimated Payout': '$5.53',
#   'Transaction #8273699085 - Delivery': '$5.53',
#   'Store Number': '70'},
#  {'Order': '34D9C5E4',
#   'Delivered': 'The order was delivered at 10:24 PM on October 22, 2023.',
#   'Pick Up Location': '5004 Wesley St, Greenville, TX 75402, USA',
#   'Order Details': {'1 × Ghost Sour Patch Redberry Can (16oz) (Energy Drinks TX)': '$4.99',
#    ' 1 × Ghost Sour Patch Blue Raspberry Can (16oz) (Energy Drinks TX)': '$4.99'},
#   'Subtotal': '$9.98',
#   'Subtotal Tax': '$0.82',
# ...

# %%
class Main2:
    def __init__(self):
        self.oh = OrderHandler()
    def convert_to_dataframes(self, orders_with_store_nums):
        orders_json_with_store_nums = self.oh.get_prettified_and_mapped_orders(orders_with_store_nums, is_raw=False)
        self.output_json(orders_json_with_store_nums, 'orders_json_with_store_nums.csv',
                         'Writing orders_json with store_num to stdout...')
    
        return self.oh.convert_flattened_orders_to_df(orders_with_store_nums)

# %%
main2 = Main2()

# %%
dfs = main2.convert_to_dataframes()
